# %%
### THIS CODE WAS ADAPTED FROM PROF ALEX SINGLETON.

# %%
import pyarrow.parquet as pq
import pandas as pd
from clustergram import Clustergram
import sklearn
#import cudf
import matplotlib.pyplot as plt

import pickle

# %%
dat = pd.read_csv('/Users/jakubwyszomierski/Desktop/PhD/GIT/OAC2021/Data/Clean/Final_variables/Aged_Scotland.csv')
dat = dat.set_index('Geography_Code')
dat = dat.drop('country', axis=1)

iteration_number = 200

# %%
### Supergroups clustering

cgram = Clustergram(range(1, 12), backend='sklearn', n_init=iteration_number)
cgram.fit(dat)
cgram.plot(figsize=(12, 8))
plt.savefig('/Users/jakubwyszomierski/Desktop/PhD/GIT/OAC2021/Plots/Clustergrams/Supergroups_OAC.pdf')
# Out:
# K=1 skipped. Mean computed from data directly.
# K=2 fitted in 78.61381506919861 seconds.
# K=3 fitted in 80.8808240890503 seconds.
# K=4 fitted in 82.45328307151794 seconds.
# K=5 fitted in 99.1318130493164 seconds.
# K=6 fitted in 106.05965805053711 seconds.
# K=7 fitted in 120.73275804519653 seconds.
# K=8 fitted in 113.93208503723145 seconds.
# K=9 fitted in 145.3974530696869 seconds.
# K=10 fitted in 185.59693384170532 seconds.
# K=11 fitted in 188.6046290397644 seconds.

# %%
#Groups clustering


dat = pd.read_csv('/Users/jakubwyszomierski/Desktop/PhD/GIT/OAC2021/Data/Clustering/OAC_assignment.csv')
dat = dat.set_index('Geography_Code')
dat = dat.drop(['Group','Subgroup'], axis=1)
dat
### Supergroups clustering

columns = ['Supergroup8']

for column in columns:
    print(column)
    for i in dat[column].unique():
        print (i)
        filtered_df = dat[dat[column] == i]
        filtered_df = filtered_df.drop('Supergroup8', axis=1)
        cgram = Clustergram(range(1, 6), backend='sklearn', n_init=iteration_number)
        cgram.fit(filtered_df)
        cgram.plot(figsize=(12, 8))
        filename = '/Users/jakubwyszomierski/Desktop/PhD/GIT/OAC2021/Plots/Clustergrams/Groups/Supergroup_' + str(i) + '.pdf'
        plt.savefig(filename)
        
        
         plt.xticks(range(1, 6), [str(math.ceil(x)) for x in cgram.dendrogram.col_level])
        
        # Save the plot with the x-axis rounded up
        filename = '/Users/jakubwyszomierski/Desktop/PhD/GIT/OAC2021/Plots/Clustergrams/Groups/Supergroup_' + str(i) + '.pdf'
        cgram.savefig(filename, format='pdf')
# Out:
# Supergroup8
# 3
# K=1 skipped. Mean computed from data directly.
# K=2 fitted in 23.780211925506592 seconds.
# K=3 fitted in 26.343381881713867 seconds.
# K=4 fitted in 47.65638613700867 seconds.
# K=5 fitted in 35.0418701171875 seconds.
# 4
# K=1 skipped. Mean computed from data directly.
# K=2 fitted in 19.484209775924683 seconds.
# K=3 fitted in 29.078014850616455 seconds.
# K=4 fitted in 38.60830521583557 seconds.
# K=5 fitted in 44.025535106658936 seconds.
# 5
# K=1 skipped. Mean computed from data directly.
# K=2 fitted in 26.199918746948242 seconds.
# K=3 fitted in 36.47754216194153 seconds.
# K=4 fitted in 42.85229301452637 seconds.
# K=5 fitted in 44.86706209182739 seconds.
# 6
# K=1 skipped. Mean computed from data directly.
# K=2 fitted in 20.052070140838623 seconds.
# K=3 fitted in 44.00614619255066 seconds.
# K=4 fitted in 46.55734705924988 seconds.
# K=5 fitted in 53.97858905792236 seconds.
# 1
# K=1 skipped. Mean computed from data directly.
# K=2 fitted in 36.76102900505066 seconds.
# K=3 fitted in 47.07175898551941 seconds.
# K=4 fitted in 54.32681584358215 seconds.
# K=5 fitted in 59.07470703125 seconds.
# 2
# K=1 skipped. Mean computed from data directly.
# K=2 fitted in 43.05131697654724 seconds.
# K=3 fitted in 52.63562607765198 seconds.
# K=4 fitted in 57.93987679481506 seconds.
# K=5 fitted in 73.6771399974823 seconds.
# 7
# K=1 skipped. Mean computed from data directly.
# K=2 fitted in 24.351459741592407 seconds.
# K=3 fitted in 25.625375270843506 seconds.
# K=4 fitted in 45.8340950012207 seconds.
# K=5 fitted in 54.99787092208862 seconds.
# 8
# K=1 skipped. Mean computed from data directly.
# K=2 fitted in 37.687471866607666 seconds.
# K=3 fitted in 43.516326904296875 seconds.
# K=4 fitted in 33.12593984603882 seconds.
# K=5 fitted in 48.102840185165405 seconds.

# %%
### Subgroup clustering

#Groups clustering


dat = pd.read_csv('/Users/jakubwyszomierski/Desktop/PhD/GIT/OAC2021/Data/Clustering/OAC_assignment.csv')
dat = dat.set_index('Geography_Code')
dat = dat.drop(['Supergroup8','Subgroup'], axis=1)
dat

columns = ['Group']

for column in columns:
    print(column)
    
    for i in dat[column].unique():
        print (i)
        filtered_df = dat[dat[column] == i]
        filtered_df = filtered_df.drop('Group', axis=1)
        cgram = Clustergram(range(1, 6), backend='sklearn', n_init=iteration_number)
        cgram.fit(filtered_df)
        cgram.plot(figsize=(12, 8))
        filename = '/Users/jakubwyszomierski/Desktop/PhD/GIT/OAC2021/Plots/Clustergrams/Subgroups/Group_' + str(i) + '.pdf'
        plt.savefig(filename)
# Out:
# Group
# 3c
# K=1 skipped. Mean computed from data directly.
# K=2 fitted in 5.666131019592285 seconds.
# K=3 fitted in 8.651525735855103 seconds.
# K=4 fitted in 9.037823915481567 seconds.
# K=5 fitted in 13.752893924713135 seconds.
# 3b
# K=1 skipped. Mean computed from data directly.
# K=2 fitted in 10.652793169021606 seconds.
# K=3 fitted in 14.617480993270874 seconds.
# K=4 fitted in 12.908383131027222 seconds.
# K=5 fitted in 16.3798828125 seconds.
# 3a
# K=1 skipped. Mean computed from data directly.
# K=2 fitted in 10.198732852935791 seconds.
# K=3 fitted in 9.050946712493896 seconds.
# K=4 fitted in 8.38826298713684 seconds.
# K=5 fitted in 10.801231145858765 seconds.
# 4c
# K=1 skipped. Mean computed from data directly.
# K=2 fitted in 7.814413070678711 seconds.
# K=3 fitted in 7.981675863265991 seconds.
# K=4 fitted in 7.052749156951904 seconds.
# K=5 fitted in 14.482337951660156 seconds.
# 4a
# K=1 skipped. Mean computed from data directly.
# K=2 fitted in 15.639127969741821 seconds.
# K=3 fitted in 20.249197959899902 seconds.
# K=4 fitted in 19.579500913619995 seconds.
# K=5 fitted in 22.68550992012024 seconds.
# 4b
# K=1 skipped. Mean computed from data directly.
# K=2 fitted in 8.853219270706177 seconds.
# K=3 fitted in 12.74510908126831 seconds.
# K=4 fitted in 11.459159135818481 seconds.
# K=5 fitted in 18.79538893699646 seconds.
# 5b
# K=1 skipped. Mean computed from data directly.
# K=2 fitted in 18.167227029800415 seconds.
# K=3 fitted in 15.774801015853882 seconds.
# K=4 fitted in 14.202711820602417 seconds.
# K=5 fitted in 15.02010202407837 seconds.
# 5a
# K=1 skipped. Mean computed from data directly.
# K=2 fitted in 12.36413311958313 seconds.
# K=3 fitted in 22.120819330215454 seconds.
# K=4 fitted in 18.737054347991943 seconds.
# K=5 fitted in 17.70856237411499 seconds.
# 6c
# K=1 skipped. Mean computed from data directly.
# K=2 fitted in 11.687607049942017 seconds.
# K=3 fitted in 13.987229347229004 seconds.
# K=4 fitted in 13.98259687423706 seconds.
# K=5 fitted in 17.62307834625244 seconds.
# 6a
# K=1 skipped. Mean computed from data directly.
# K=2 fitted in 8.715010166168213 seconds.
# K=3 fitted in 12.777751684188843 seconds.
# K=4 fitted in 29.131989002227783 seconds.
# K=5 fitted in 38.46368885040283 seconds.
# 1b
# K=1 skipped. Mean computed from data directly.
# K=2 fitted in 16.89318084716797 seconds.
# K=3 fitted in 29.196528911590576 seconds.
# K=4 fitted in 28.616301774978638 seconds.
# K=5 fitted in 34.964505195617676 seconds.
# 2c
# K=1 skipped. Mean computed from data directly.
# K=2 fitted in 15.347190856933594 seconds.
# K=3 fitted in 21.39528775215149 seconds.
# K=4 fitted in 33.4257071018219 seconds.
